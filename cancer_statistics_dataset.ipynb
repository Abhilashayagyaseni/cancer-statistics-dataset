# %% [markdown]
# ### Working on real project with python
# #### (A part of big data analysis)

# %% [markdown]
# ## The Cancer Statistics(WHO) dataset 2020
# Cancer is a large group of diseases that can start in almost any organ or tissue of the body when abnormal cells grow uncontrollably, go beyond their usual boundaries to invade adjoining parts of the body and/or spread to other organs.
# Cancer is the second leading cause of death globally, accounting for an estimated 9.6 million deaths, or one in six deaths, in 2018. Lung, prostate, colorectal, stomach and liver cancer are the most common types of cancer in men, while breast, colorectal, lung, cervical and thyroid cancer are the most common among women.

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\abhiy\Downloads\cancer_data.csv")

# %% [markdown]
# #### Problem - Find the total number of cancer type in body?

# %%
data.head(2)
data['cancer_type'].nunique()
# Out:
# 35

# %% [markdown]
# #### Problem - Find the name of all type of cancers?

# %%
data['cancer_type'].unique()
# Out:
# array(['Anus', 'Bladder', 'Brain, central nervous system', 'Breast',
#        'Cervix uteri', 'Colon', 'Corpus uteri', 'Gallbladder',
#        'Hodgkin lymphoma', 'Hypopharynx', 'Kaposi sarcoma', 'Kidney',
#        'Larynx', 'Leukaemia', 'Lip, oral cavity', 'Liver', 'Lung',
#        'Melanoma of skin', 'Mesothelioma', 'Multiple myeloma',
#        'Nasopharynx', 'Non-Hodgkin lymphoma', 'Oesophagus', 'Oropharynx',
#        'Ovary', 'Pancreas', 'Penis', 'Prostate', 'Rectum',
#        'Salivary glands', 'Stomach', 'Testis', 'Thyroid', 'Vagina',
#        'Vulva'], dtype=object)

# %% [markdown]
# #### Problem - Find the name of cancer where death rank is 1.

# %%
data.loc[data.death_rank == 1,['cancer_type','death_rank']]
# Out:
#   cancer_type  death_rank
# 3      Breast           1

# %% [markdown]
# #### Problem - Find the name of 5 most common type of cancers?

# %%
# Out:
#                       cancer_type  new_cases_number  new_cases_rank  \
# 0                            Anus              5452              30
# 1                         Bladder             21096              17
# 2   Brain, central nervous system             31460              14
# 3                          Breast            178361               1
# 4                    Cervix uteri            123907               3
# 5                           Colon             31646              13
# 6                    Corpus uteri             16413              22
# 7                     Gallbladder             19570              20
# 8                Hodgkin lymphoma              9221              26
# 9                     Hypopharynx             28489              15
# 10                 Kaposi sarcoma                66              35
# 11                         Kidney             16861              21
# 12                         Larynx             34687              11
# ...

# %% [markdown]
# #### Problem - Find the name of cancers with lowest death percentage?

# %% [markdown]
# #### Problem - Find the name of cancer with lowest and highest new case.

# %% [markdown]
# #### Problem - Find the name of all type of cancers?

# %%
data
# Out:
#                       cancer_type  new_cases_number  new_cases_rank  \
# 0                            Anus              5452              30
# 1                         Bladder             21096              17
# 2   Brain, central nervous system             31460              14
# 3                          Breast            178361               1
# 4                    Cervix uteri            123907               3
# 5                           Colon             31646              13
# 6                    Corpus uteri             16413              22
# 7                     Gallbladder             19570              20
# 8                Hodgkin lymphoma              9221              26
# 9                     Hypopharynx             28489              15
# 10                 Kaposi sarcoma                66              35
# 11                         Kidney             16861              21
# 12                         Larynx             34687              11
# ...
